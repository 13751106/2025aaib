# %% [markdown]
# (把注音入法關掉)
#
# ```java
# // week03-2size_blackground_ellipse
# size(400, 400); //開一個視窗,大小是400X400
# background(255, 255, 242); // 背景用淡黃色
# ellipse(200, 100, 50, 30); // 在200,100 放 30,30 橢圓
# ```

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ```java
# // week03-3_void_setup_void_draw_if_mousePressed_else
# void setup() {
#   size(400, 400);
# }
# void draw(){ //
#   if(mousePressed) background(255, 0, 0);  // 紅色
#   else background(0, 255, 0); // 綠色
# }
# ```
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ```java
# //week03-4_mousePressed_mouseX_mouseY_float_x_y
# void setup() {
#   size(400, 400);
# }
# float x=200, y=200;
# void draw() {
#   //if(mousePressed) ellipse(mouseX, mouseY, 50, 30);
#   background(#5DD7FA);
#   if(mousePressed){
#     x=(x + mouseX)/2;
#     y=(y + mouseX)/2;
#   }
# ellipse(x, y, 50, 30);
# }
# ```
# ![image.png](data:image/png;base64,...)
